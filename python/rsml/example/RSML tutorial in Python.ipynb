# %% [markdown]
# # RSML Tutorial in Python

# %% [markdown]
# First, we activate matplotlib and qt in the Notebook

# %%
# %matplotlib inline
# %gui qt

# %% [markdown]
# Then, we import main modules and function to work with RSML format in Python

# %%
from openalea.deploy.shared_data import shared_data
import rsml

# %%
data = shared_data(rsml)
files = data.glob('*.rsml')

# %%
# Convert RSML file into an MTG and plot it
print [str(f.basename()) for f in files]

mtgs = [rsml.rsml2mtg(files[0]) for f in files]

# Plot it
rsml.plot2d(mtgs[0])
# Out:
# ['lupin_aero.rsml', 'root_ramifie.rsml']
# Invalid Annotation format
# Invalid Annotation format

# %%
rsml.plot2d(mtgs[1])
